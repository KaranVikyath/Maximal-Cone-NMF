# %% [markdown]
# ### Import packages and functions

# %%
import numpy as np
from scipy.optimize import nnls

# Import your algorithm
from maximal_cone_nmf import directional_method
from matrix_utils import generate_matrices
import pandas as pd

# %% [markdown]
# ### Generate Synthetic Data

# %%
df_iris = pd.read_csv(r"iris.csv")
data_iris = df_iris.iloc[:, :-1].values
X = data_iris.T  # shape: (features, samples)
r = 2 # Use the find_ambient_dim.py to find the approximate rank
# Out:
#   Cell In[2], line 1
#     X, r = # load data here, you the find_ambient_dim.py to find approximate r
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Run Maximal Cone NMF to find the extreme rays

# %%
# Run the no-parameter directional method
facets, W = directional_method(X, r=r)

print("Number of facets found:", len(facets))
print("W shape:", W.shape)
# Out:
# Number of facets found: 197
# W shape: (100, 197)

# %% [markdown]
# ### Run nnls to find H

# %%
# Compute H via NNLS
k = W.shape[1]
H = np.zeros((k, X.shape[1]))

for j in range(X.shape[1]):
    h_j, _ = nnls(W, X[:, j])
    H[:, j] = h_j

print("H shape:", H.shape)
# Out:
# H shape: (197, 100)

# %% [markdown]
# ### Reconstruction Error ||X-X_hat||_F / ||X||_F

# %%
X_hat = W @ H
reconstruction_error = np.linalg.norm(X - X_hat) / np.linalg.norm(X)

print("Relative reconstruction error:", reconstruction_error)
# Out:
# Relative reconstruction error: 0.03834236159826254
